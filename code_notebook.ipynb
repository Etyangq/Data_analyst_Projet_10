# %% [markdown]
# **<font size=6>Projet 10: Détectez des faux billets avec Python</font>**

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Partie-1---Importation-des-données-'billets'" data-toc-modified-id="Partie-1---Importation-des-données-'billets'-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Partie 1 - Importation des données 'billets'</a></span></li><li><span><a href="#Partie-2---Nettoyage-du-fichier" data-toc-modified-id="Partie-2---Nettoyage-du-fichier-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Partie 2 - Nettoyage du fichier</a></span><ul class="toc-item"><li><span><a href="#Vérifier-les-doublons-avec-toutes-les-colonnes." data-toc-modified-id="Vérifier-les-doublons-avec-toutes-les-colonnes.-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Vérifier les doublons avec toutes les colonnes.</a></span></li><li><span><a href="#Valeurs-manquantes" data-toc-modified-id="Valeurs-manquantes-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Valeurs manquantes</a></span><ul class="toc-item"><li><span><a href="#Dataframe-comprenant-les-valeurs-manquantes:" data-toc-modified-id="Dataframe-comprenant-les-valeurs-manquantes:-2.2.1"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span>Dataframe comprenant les valeurs manquantes:</a></span></li><li><span><a href="#Dataframe-ne-comprenant-pas-les-valeurs-manquantes:" data-toc-modified-id="Dataframe-ne-comprenant-pas-les-valeurs-manquantes:-2.2.2"><span class="toc-item-num">2.2.2&nbsp;&nbsp;</span>Dataframe ne comprenant pas les valeurs manquantes:</a></span></li><li><span><a href="#Vérification-de-corrélation-entre-les-variables" data-toc-modified-id="Vérification-de-corrélation-entre-les-variables-2.2.3"><span class="toc-item-num">2.2.3&nbsp;&nbsp;</span>Vérification de corrélation entre les variables</a></span></li><li><span><a href="#Régression-linéaire-multiple" data-toc-modified-id="Régression-linéaire-multiple-2.2.4"><span class="toc-item-num">2.2.4&nbsp;&nbsp;</span>Régression linéaire multiple</a></span><ul class="toc-item"><li><span><a href="#Régresser-margin_low-en-fonction-des-autres-variables." data-toc-modified-id="Régresser-margin_low-en-fonction-des-autres-variables.-2.2.4.1"><span class="toc-item-num">2.2.4.1&nbsp;&nbsp;</span>Régresser margin_low en fonction des autres variables.</a></span></li><li><span><a href="#Retirez-les-variables-non-significatives" data-toc-modified-id="Retirez-les-variables-non-significatives-2.2.4.2"><span class="toc-item-num">2.2.4.2&nbsp;&nbsp;</span>Retirez les variables non significatives</a></span></li><li><span><a href="#Vérifier-la-colinéarité-des-variables" data-toc-modified-id="Vérifier-la-colinéarité-des-variables-2.2.4.3"><span class="toc-item-num">2.2.4.3&nbsp;&nbsp;</span>Vérifier la colinéarité des variables</a></span></li><li><span><a href="#Testez-l’homoscédasticité" data-toc-modified-id="Testez-l’homoscédasticité-2.2.4.4"><span class="toc-item-num">2.2.4.4&nbsp;&nbsp;</span>Testez l’homoscédasticité</a></span></li><li><span><a href="#Testez-la-normalité-des-résidus" data-toc-modified-id="Testez-la-normalité-des-résidus-2.2.4.5"><span class="toc-item-num">2.2.4.5&nbsp;&nbsp;</span>Testez la normalité des résidus</a></span></li></ul></li><li><span><a href="#Prédiction-des-valeurs-manquantes-avec-régression-linéaire-multiple" data-toc-modified-id="Prédiction-des-valeurs-manquantes-avec-régression-linéaire-multiple-2.2.5"><span class="toc-item-num">2.2.5&nbsp;&nbsp;</span>Prédiction des valeurs manquantes avec régression linéaire multiple</a></span><ul class="toc-item"><li><span><a href="#Prédiction" data-toc-modified-id="Prédiction-2.2.5.1"><span class="toc-item-num">2.2.5.1&nbsp;&nbsp;</span>Prédiction</a></span></li><li><span><a href="#Reformer-le-dataframe-avec-les-valeurs-manquantes-ajoutées:" data-toc-modified-id="Reformer-le-dataframe-avec-les-valeurs-manquantes-ajoutées:-2.2.5.2"><span class="toc-item-num">2.2.5.2&nbsp;&nbsp;</span>Reformer le dataframe avec les valeurs manquantes ajoutées:</a></span></li><li><span><a href="#Ajouter-les-valeurs-manquantes-dans-la-dataframe-'billets'" data-toc-modified-id="Ajouter-les-valeurs-manquantes-dans-la-dataframe-'billets'-2.2.5.3"><span class="toc-item-num">2.2.5.3&nbsp;&nbsp;</span>Ajouter les valeurs manquantes dans la dataframe 'billets'</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#Partie-3---Exploration-des-données" data-toc-modified-id="Partie-3---Exploration-des-données-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Partie 3 - Exploration des données</a></span><ul class="toc-item"><li><span><a href="#Compte-le-nombre-de-vrais-billets-et-faux-billets" data-toc-modified-id="Compte-le-nombre-de-vrais-billets-et-faux-billets-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Compte le nombre de vrais billets et faux billets</a></span></li><li><span><a href="#Distribution-des-données-des-variables" data-toc-modified-id="Distribution-des-données-des-variables-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Distribution des données des variables</a></span><ul class="toc-item"><li><span><a href="#Visualisation-des-distributions-à-l'aide-d'histogrammes-pour-vérifier-la-forme-des-variables." data-toc-modified-id="Visualisation-des-distributions-à-l'aide-d'histogrammes-pour-vérifier-la-forme-des-variables.-3.2.1"><span class="toc-item-num">3.2.1&nbsp;&nbsp;</span>Visualisation des distributions à l'aide d'histogrammes pour vérifier la forme des variables.</a></span></li><li><span><a href="#Teste-de-normalité-(Shapiro-Wilk-)" data-toc-modified-id="Teste-de-normalité-(Shapiro-Wilk-)-3.2.2"><span class="toc-item-num">3.2.2&nbsp;&nbsp;</span>Teste de normalité (Shapiro-Wilk )</a></span></li></ul></li><li><span><a href="#Visualiser-les-caractéristiques-des-billets-selon-qu'ils-soient-vrais-ou-faux" data-toc-modified-id="Visualiser-les-caractéristiques-des-billets-selon-qu'ils-soient-vrais-ou-faux-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Visualiser les caractéristiques des billets selon qu'ils soient vrais ou faux</a></span><ul class="toc-item"><li><span><a href="#Boite-à-moustache-length-/-is_genuine--et-margin_low-/-is_genuine" data-toc-modified-id="Boite-à-moustache-length-/-is_genuine--et-margin_low-/-is_genuine-3.3.1"><span class="toc-item-num">3.3.1&nbsp;&nbsp;</span>Boite à moustache length / is_genuine  et margin_low / is_genuine</a></span></li><li><span><a href="#Test-ANOVA" data-toc-modified-id="Test-ANOVA-3.3.2"><span class="toc-item-num">3.3.2&nbsp;&nbsp;</span>Test ANOVA</a></span></li></ul></li></ul></li><li><span><a href="#Partie-4---Tester-les-3-modèles-(K-means,-K-NN-et-Régression-Logistique)" data-toc-modified-id="Partie-4---Tester-les-3-modèles-(K-means,-K-NN-et-Régression-Logistique)-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Partie 4 - Tester les 3 modèles (K-means, K-NN et Régression Logistique)</a></span><ul class="toc-item"><li><span><a href="#ACP-(Analyse-en-composantes-principales)" data-toc-modified-id="ACP-(Analyse-en-composantes-principales)-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>ACP (Analyse en composantes principales)</a></span><ul class="toc-item"><li><span><a href="#Préparation-des-données-pour-l'ACP" data-toc-modified-id="Préparation-des-données-pour-l'ACP-4.1.1"><span class="toc-item-num">4.1.1&nbsp;&nbsp;</span>Préparation des données pour l'ACP</a></span></li><li><span><a href="#Calcul-des-composantes-principales" data-toc-modified-id="Calcul-des-composantes-principales-4.1.2"><span class="toc-item-num">4.1.2&nbsp;&nbsp;</span>Calcul des composantes principales</a></span></li><li><span><a href="#Cercle-des-corrélations" data-toc-modified-id="Cercle-des-corrélations-4.1.3"><span class="toc-item-num">4.1.3&nbsp;&nbsp;</span>Cercle des corrélations</a></span></li><li><span><a href="#Projection-des-individus-sur-le-plan-factoriel-selon-le-type-de-billet" data-toc-modified-id="Projection-des-individus-sur-le-plan-factoriel-selon-le-type-de-billet-4.1.4"><span class="toc-item-num">4.1.4&nbsp;&nbsp;</span>Projection des individus sur le plan factoriel selon le type de billet</a></span></li></ul></li><li><span><a href="#K-means-(clustering-non-supervisé)" data-toc-modified-id="K-means-(clustering-non-supervisé)-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>K-means (clustering non-supervisé)</a></span><ul class="toc-item"><li><span><a href="#Projection-des-individus-sur-le-plan-factoriel-F1-et-F2-par-cluster" data-toc-modified-id="Projection-des-individus-sur-le-plan-factoriel-F1-et-F2-par-cluster-4.2.1"><span class="toc-item-num">4.2.1&nbsp;&nbsp;</span>Projection des individus sur le plan factoriel F1 et F2 par cluster</a></span></li><li><span><a href="#Matrice-de-confusion-K--means" data-toc-modified-id="Matrice-de-confusion-K--means-4.2.2"><span class="toc-item-num">4.2.2&nbsp;&nbsp;</span>Matrice de confusion K- means</a></span></li><li><span><a href="#Classification-report" data-toc-modified-id="Classification-report-4.2.3"><span class="toc-item-num">4.2.3&nbsp;&nbsp;</span>Classification report</a></span></li></ul></li><li><span><a href="#Régression-logistique-(classification-supervisé)" data-toc-modified-id="Régression-logistique-(classification-supervisé)-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Régression logistique (classification supervisé)</a></span><ul class="toc-item"><li><span><a href="#Préparer-les-données" data-toc-modified-id="Préparer-les-données-4.3.1"><span class="toc-item-num">4.3.1&nbsp;&nbsp;</span>Préparer les données</a></span></li><li><span><a href="#Création-du-modèle-de-régression-logistique" data-toc-modified-id="Création-du-modèle-de-régression-logistique-4.3.2"><span class="toc-item-num">4.3.2&nbsp;&nbsp;</span>Création du modèle de régression logistique</a></span></li><li><span><a href="#Prédictions" data-toc-modified-id="Prédictions-4.3.3"><span class="toc-item-num">4.3.3&nbsp;&nbsp;</span>Prédictions</a></span></li><li><span><a href="#Matrice-de-confusion-(régression-logistique)" data-toc-modified-id="Matrice-de-confusion-(régression-logistique)-4.3.4"><span class="toc-item-num">4.3.4&nbsp;&nbsp;</span>Matrice de confusion (régression logistique)</a></span></li><li><span><a href="#Évaluation-du-modèle-avec-les-scores" data-toc-modified-id="Évaluation-du-modèle-avec-les-scores-4.3.5"><span class="toc-item-num">4.3.5&nbsp;&nbsp;</span>Évaluation du modèle avec les scores</a></span><ul class="toc-item"><li><span><a href="#Accuracy-score" data-toc-modified-id="Accuracy-score-4.3.5.1"><span class="toc-item-num">4.3.5.1&nbsp;&nbsp;</span>Accuracy score</a></span></li><li><span><a href="#Le-coefficient-de-détermination-R2" data-toc-modified-id="Le-coefficient-de-détermination-R2-4.3.5.2"><span class="toc-item-num">4.3.5.2&nbsp;&nbsp;</span>Le coefficient de détermination R2</a></span></li><li><span><a href="#Cross-Validation-(-Régression-logistique)" data-toc-modified-id="Cross-Validation-(-Régression-logistique)-4.3.5.3"><span class="toc-item-num">4.3.5.3&nbsp;&nbsp;</span>Cross-Validation ( Régression logistique)</a></span></li></ul></li></ul></li><li><span><a href="#K-NN-(classification-supervisé)" data-toc-modified-id="K-NN-(classification-supervisé)-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>K-NN (classification supervisé)</a></span><ul class="toc-item"><li><span><a href="#Préparer-les-données" data-toc-modified-id="Préparer-les-données-4.4.1"><span class="toc-item-num">4.4.1&nbsp;&nbsp;</span>Préparer les données</a></span></li><li><span><a href="#Choisir-le-nombre-optimal-de-K" data-toc-modified-id="Choisir-le-nombre-optimal-de-K-4.4.2"><span class="toc-item-num">4.4.2&nbsp;&nbsp;</span>Choisir le nombre optimal de K</a></span></li><li><span><a href="#Création-de-modèle-K-NN" data-toc-modified-id="Création-de-modèle-K-NN-4.4.3"><span class="toc-item-num">4.4.3&nbsp;&nbsp;</span>Création de modèle K-NN</a></span></li><li><span><a href="#Prédictions" data-toc-modified-id="Prédictions-4.4.4"><span class="toc-item-num">4.4.4&nbsp;&nbsp;</span>Prédictions</a></span></li><li><span><a href="#Matrice-de-confusion-(K-NN)" data-toc-modified-id="Matrice-de-confusion-(K-NN)-4.4.5"><span class="toc-item-num">4.4.5&nbsp;&nbsp;</span>Matrice de confusion (K-NN)</a></span></li><li><span><a href="#Évaluation-du-modèle-avec-les-scores" data-toc-modified-id="Évaluation-du-modèle-avec-les-scores-4.4.6"><span class="toc-item-num">4.4.6&nbsp;&nbsp;</span>Évaluation du modèle avec les scores</a></span><ul class="toc-item"><li><span><a href="#Accuracy-score" data-toc-modified-id="Accuracy-score-4.4.6.1"><span class="toc-item-num">4.4.6.1&nbsp;&nbsp;</span>Accuracy score</a></span></li><li><span><a href="#Le-coefficient-de-détermination-R2" data-toc-modified-id="Le-coefficient-de-détermination-R2-4.4.6.2"><span class="toc-item-num">4.4.6.2&nbsp;&nbsp;</span>Le coefficient de détermination R2</a></span></li><li><span><a href="#Cross-Validation-(K-NN-)" data-toc-modified-id="Cross-Validation-(K-NN-)-4.4.6.3"><span class="toc-item-num">4.4.6.3&nbsp;&nbsp;</span>Cross-Validation (K-NN )</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#Conclusion" data-toc-modified-id="Conclusion-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Conclusion</a></span></li><li><span><a href="#Programme-de-détection-avec-régression-logistique" data-toc-modified-id="Programme-de-détection-avec-régression-logistique-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Programme de détection avec régression logistique</a></span><ul class="toc-item"><li><span><a href="#Importation-et-prédiction-des-données-du-fichier-'billets_production'" data-toc-modified-id="Importation-et-prédiction-des-données-du-fichier-'billets_production'-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Importation et prédiction des données du fichier 'billets_production'</a></span></li><li><span><a href="#Fonction-du-modèle-de-détection-avec-régression-logistique" data-toc-modified-id="Fonction-du-modèle-de-détection-avec-régression-logistique-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Fonction du modèle de détection avec régression logistique</a></span></li></ul></li></ul></div>

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

import statsmodels.api as sm
import statsmodels.formula.api as smf
from scipy.stats import shapiro
from statsmodels.stats.outliers_influence import variance_inflation_factor
import statsmodels
from scipy import stats

from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

from sklearn.cluster import KMeans
from sklearn.cluster import AgglomerativeClustering
from sklearn import decomposition, preprocessing,cluster
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.linear_model import LogisticRegression
from sklearn import neighbors

# %% [markdown]
# # Partie 1 - Importation des données 'billets'

# %% [markdown]
# Nous disposons actuellement de six informations géométriques sur un billet :
# - length : la longueur du billet (en mm) ;
# - height_left : la hauteur du billet (mesurée sur le côté gauche, en mm) ;
# - height_right : la hauteur du billet (mesurée sur le côté droit, en mm) ;
# - margin_up : la marge entre le bord supérieur du billet et l'image de celui-ci (en mm) ;
# - margin_low : la marge entre le bord inférieur du billet et l'image de celui-ci (en mm) ;
# - diagonal : la diagonale du billet (en mm).

# %%
billets = pd.read_csv("D:/Open_work/P10/doc_origine/billets.csv",delimiter=';')
billets.head()
# Out:
#    is_genuine  diagonal  height_left  height_right  margin_low  margin_up  \
# 0        True    171.81       104.86        104.95        4.52       2.89
# 1        True    171.46       103.36        103.66        3.77       2.99
# 2        True    172.69       104.48        103.50        4.40       2.94
# 3        True    171.36       103.91        103.94        3.62       3.01
# 4        True    171.73       104.28        103.46        4.04       3.48
#
#    length
# 0  112.83
# 1  113.09
# 2  113.16
# 3  113.51
# 4  112.54

# %%
billets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   is_genuine    1500 non-null   bool
#  1   diagonal      1500 non-null   float64
#  2   height_left   1500 non-null   float64
#  3   height_right  1500 non-null   float64
#  4   margin_low    1463 non-null   float64
#  5   margin_up     1500 non-null   float64
#  6   length        1500 non-null   float64
# dtypes: bool(1), float64(6)
# memory usage: 71.9 KB

# %%
billets.describe()
# Out:
#           diagonal  height_left  height_right   margin_low    margin_up  \
# count  1500.000000  1500.000000   1500.000000  1463.000000  1500.000000
# mean    171.958440   104.029533    103.920307     4.485967     3.151473
# std       0.305195     0.299462      0.325627     0.663813     0.231813
# min     171.040000   103.140000    102.820000     2.980000     2.270000
# 25%     171.750000   103.820000    103.710000     4.015000     2.990000
# 50%     171.960000   104.040000    103.920000     4.310000     3.140000
# 75%     172.170000   104.230000    104.150000     4.870000     3.310000
# max     173.010000   104.880000    104.950000     6.900000     3.910000
#
#            length
# count  1500.00000
# mean    112.67850
# std       0.87273
# min     109.49000
# 25%     112.03000
# 50%     112.96000
# 75%     113.34000
# max     114.44000

# %%
billets.shape
# Out:
# (1500, 7)

# %% [markdown]
# # Partie 2 - Nettoyage du fichier

# %% [markdown]
# ## Vérifier les doublons avec toutes les colonnes.

# %%
billets.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Valeurs manquantes

# %%
billets.isna().sum()
# Out:
# is_genuine       0
# diagonal         0
# height_left      0
# height_right     0
# margin_low      37
# margin_up        0
# length           0
# dtype: int64

# %%
billets.isna().mean()
# Out:
# is_genuine      0.000000
# diagonal        0.000000
# height_left     0.000000
# height_right    0.000000
# margin_low      0.024667
# margin_up       0.000000
# length          0.000000
# dtype: float64

# %% [markdown]
# ### Dataframe comprenant les valeurs manquantes:

# %%
donnees_nan = billets[billets.isnull().any(axis=1)]
donnees_nan.head()
# Out:
#      is_genuine  diagonal  height_left  height_right  margin_low  margin_up  \
# 72         True    171.94       103.89        103.45         NaN       3.25
# 99         True    171.93       104.07        104.18         NaN       3.14
# 151        True    172.07       103.80        104.38         NaN       3.02
# 197        True    171.45       103.66        103.80         NaN       3.62
# 241        True    171.83       104.14        104.06         NaN       3.02
#
#      length
# 72   112.79
# 99   113.08
# 151  112.93
# 197  113.27
# 241  112.36

# %% [markdown]
# On trouve que "margin_low" comprend 37 valeurs manquantes (1463 valeurs sur les 1500 attendues), soit 2%.

# %% [markdown]
# ### Dataframe ne comprenant pas les valeurs manquantes:

# %%
donnees_sans_nan = billets.dropna(how='any')

# %%
donnees_sans_nan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1463 entries, 0 to 1499
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   is_genuine    1463 non-null   bool
#  1   diagonal      1463 non-null   float64
#  2   height_left   1463 non-null   float64
#  3   height_right  1463 non-null   float64
#  4   margin_low    1463 non-null   float64
#  5   margin_up     1463 non-null   float64
#  6   length        1463 non-null   float64
# dtypes: bool(1), float64(6)
# memory usage: 81.4 KB

# %% [markdown]
# ### Vérification de corrélation entre les variables

# %%
plt.figure(figsize=(16,9))

sns.heatmap(donnees_sans_nan.corr(), annot=True)

plt.show()

# %% [markdown]
# La heatmap permet de mettre en relief les corrélations observables dans le dataframe. Dans cette heatmap, on peut mettre en évidence un lien positif fort entre la variable 'length' et 'is_genuine’, 'margin_low’ et ‘margin_up', un lien négatif fort entre 'margin_low' et 'is_genuine’, 'margin_low’ et ‘length’.

# %% [markdown]
# ### Régression linéaire multiple
# Appliquons la régression linéaire multiple à l'échantillon 'billets'. Modélisons 'margin_low' en fonction de toutes les autres variables.

# %% [markdown]
# #### Régresser margin_low en fonction des autres variables.

# %%
reg_multi = smf.ols('margin_low~is_genuine+diagonal+height_left+height_right+margin_up+length', data=donnees_sans_nan).fit()
print(reg_multi.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:             margin_low   R-squared:                       0.617
# Model:                            OLS   Adj. R-squared:                  0.615
# Method:                 Least Squares   F-statistic:                     390.7
# Date:                Thu, 01 Sep 2022   Prob (F-statistic):          4.75e-299
# Time:                        11:31:33   Log-Likelihood:                -774.14
# No. Observations:                1463   AIC:                             1562.
# Df Residuals:                    1456   BIC:                             1599.
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept              2.8668      8.316      0.345      0.730     -13.445      19.179
# ...

# %% [markdown]
# On constate ici que certains paramètres ne sont pas significativement différents de 0, car leur p-valeur n'est pas inférieure à 5 %, le niveau de test que nous souhaitons.
#
# Le  𝑅2  vaut environ 0.617, et le  𝑅2  ajusté est d'environ 0.615.

# %% [markdown]
# #### Retirez les variables non significatives
# On va donc maintenant retirer les variables non significatives: diagonal,'length','height_right','height_left', car ils ont une p-valeur > 0.05.

# %%
reg_multi = smf.ols('margin_low~is_genuine+margin_up', data=donnees_sans_nan).fit()
print(reg_multi.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:             margin_low   R-squared:                       0.617
# Model:                            OLS   Adj. R-squared:                  0.616
# Method:                 Least Squares   F-statistic:                     1174.
# Date:                Thu, 01 Sep 2022   Prob (F-statistic):          1.24e-304
# Time:                        11:31:33   Log-Likelihood:                -774.73
# No. Observations:                1463   AIC:                             1555.
# Df Residuals:                    1460   BIC:                             1571.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept              5.9263      0.198     30.003      0.000       5.539       6.314
# ...

# %% [markdown]
#  **On peut donc utiliser ce modèle (avec les variables 'is_genuine' et 'margin_up') à des fins de prévision de la variable 'margin_low' !**
#
# Le 𝑅2 vaut environ 0.617, et le 𝑅2 ajusté est d'environ 0.616.

# %% [markdown]
# #### Vérifier la colinéarité des variables

# %%
variables = reg_multi.model.exog
[variance_inflation_factor(variables, i) for i in np.arange(1,variables.shape[1])]
# Out:
# [1.5938854494007753, 1.5938854494007746]

# %% [markdown]
# Ici, tous les coefficients sont inférieurs à 10, il n'y a donc pas de problème de colinéarité.

# %% [markdown]
# #### Testez l’homoscédasticité
# On peut également tester l’homoscédasticité (c'est-à-dire la constance de la variance) des résidus :

# %%
_, pval, __, f_pval = statsmodels.stats.diagnostic.het_breuschpagan(reg_multi.resid, variables)
print('p value test Breusch Pagan:', pval)
# Out:
# p value test Breusch Pagan: 3.2033559115838186e-36

# %% [markdown]
# La p-valeur ici est inférieure à  5 %, on rejette l'hypothèse  𝐻0  selon laquelle les variances sont constantes (l'hypothèse d’homoscédasticité).

# %% [markdown]
# #### Testez la normalité des résidus

# %%
shapiro(reg_multi.resid)
# Out:
# ShapiroResult(statistic=0.9936248064041138, pvalue=6.20942773821298e-06)

# %% [markdown]
# Ici, l'hypothèse de normalité est remise en cause (p-value = 6.2e-06 < 0.05).
#
# Néanmoins, l'observation des résidus, le fait qu'ils ne soient pas très différents d'une distribution symétrique, et le fait que l'échantillon soit de taille suffisante (supérieure à 30) permettent de dire que les résultats obtenus par le modèle linéaire gaussien ne sont pas absurdes, même si le résidu n'est pas considéré comme étant gaussien.

# %%
df_res=donnees_sans_nan.copy()

# %%
df_res['residu_s'] = reg_multi.resid

# %%
plt.figure(figsize=(6,6))
plt.hist(df_res['residu_s'], density=True)
plt.xlabel('Résidus')
plt.title('Histogramme des résidus')
plt.show()

# %% [markdown]
# L’allure de l’histogramme est assez classique : centrée et à peu près symétrique.

# %% [markdown]
# ### Prédiction des valeurs manquantes avec régression linéaire multiple

# %%
donnees_nan.head()
# Out:
#      is_genuine  diagonal  height_left  height_right  margin_low  margin_up  \
# 72         True    171.94       103.89        103.45         NaN       3.25
# 99         True    171.93       104.07        104.18         NaN       3.14
# 151        True    172.07       103.80        104.38         NaN       3.02
# 197        True    171.45       103.66        103.80         NaN       3.62
# 241        True    171.83       104.14        104.06         NaN       3.02
#
#      length
# 72   112.79
# 99   113.08
# 151  112.93
# 197  113.27
# 241  112.36

# %%
X_nan = donnees_nan.drop(['margin_low'], axis=1)

# %% [markdown]
# #### Prédiction

# %%
y_nan = reg_multi.predict(X_nan)

# %% [markdown]
# #### Reformer le dataframe avec les valeurs manquantes ajoutées:

# %%
X_nan['margin_low'] = y_nan
X_nan.head()
# Out:
#      is_genuine  diagonal  height_left  height_right  margin_up  length  \
# 72         True    171.94       103.89        103.45       3.25  112.79
# 99         True    171.93       104.07        104.18       3.14  113.08
# 151        True    172.07       103.80        104.38       3.02  112.93
# 197        True    171.45       103.66        103.80       3.62  113.27
# 241        True    171.83       104.14        104.06       3.02  112.36
#
#      margin_low
# 72     4.074248
# 99     4.097561
# 151    4.122994
# 197    3.995830
# 241    4.122994

# %%
# Chnager l'ordre des colonnes
order = ['is_genuine','diagonal','height_left','height_right','margin_low','margin_up','length']
X_nan = X_nan[order]
X_nan.head()
# Out:
#      is_genuine  diagonal  height_left  height_right  margin_low  margin_up  \
# 72         True    171.94       103.89        103.45    4.074248       3.25
# 99         True    171.93       104.07        104.18    4.097561       3.14
# 151        True    172.07       103.80        104.38    4.122994       3.02
# 197        True    171.45       103.66        103.80    3.995830       3.62
# 241        True    171.83       104.14        104.06    4.122994       3.02
#
#      length
# 72   112.79
# 99   113.08
# 151  112.93
# 197  113.27
# 241  112.36

# %%
X_nan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 37 entries, 72 to 1438
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   is_genuine    37 non-null     bool
#  1   diagonal      37 non-null     float64
#  2   height_left   37 non-null     float64
#  3   height_right  37 non-null     float64
#  4   margin_low    37 non-null     float64
#  5   margin_up     37 non-null     float64
#  6   length        37 non-null     float64
# dtypes: bool(1), float64(6)
# memory usage: 2.1 KB

# %% [markdown]
# #### Ajouter les valeurs manquantes dans la dataframe 'billets'

# %%
donnees_sans_nan.head()
# Out:
#    is_genuine  diagonal  height_left  height_right  margin_low  margin_up  \
# 0        True    171.81       104.86        104.95        4.52       2.89
# 1        True    171.46       103.36        103.66        3.77       2.99
# 2        True    172.69       104.48        103.50        4.40       2.94
# 3        True    171.36       103.91        103.94        3.62       3.01
# 4        True    171.73       104.28        103.46        4.04       3.48
#
#    length
# 0  112.83
# 1  113.09
# 2  113.16
# 3  113.51
# 4  112.54

# %%
donnees_sans_nan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1463 entries, 0 to 1499
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   is_genuine    1463 non-null   bool
#  1   diagonal      1463 non-null   float64
#  2   height_left   1463 non-null   float64
#  3   height_right  1463 non-null   float64
#  4   margin_low    1463 non-null   float64
#  5   margin_up     1463 non-null   float64
#  6   length        1463 non-null   float64
# dtypes: bool(1), float64(6)
# memory usage: 81.4 KB

# %%
# Ajouter les lignes qui ont remplacé les valeurs nulles
billets = pd.concat([donnees_sans_nan, X_nan])

# %%
billets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1500 entries, 0 to 1438
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   is_genuine    1500 non-null   bool
#  1   diagonal      1500 non-null   float64
#  2   height_left   1500 non-null   float64
#  3   height_right  1500 non-null   float64
#  4   margin_low    1500 non-null   float64
#  5   margin_up     1500 non-null   float64
#  6   length        1500 non-null   float64
# dtypes: bool(1), float64(6)
# memory usage: 83.5 KB

# %%
billets.shape
# Out:
# (1500, 7)

# %%
billets.describe()
# Out:
#           diagonal  height_left  height_right   margin_low    margin_up  \
# count  1500.000000  1500.000000   1500.000000  1500.000000  1500.000000
# mean    171.958440   104.029533    103.920307     4.482863     3.151473
# std       0.305195     0.299462      0.325627     0.659849     0.231813
# min     171.040000   103.140000    102.820000     2.980000     2.270000
# 25%     171.750000   103.820000    103.710000     4.027500     2.990000
# 50%     171.960000   104.040000    103.920000     4.310000     3.140000
# 75%     172.170000   104.230000    104.150000     4.870000     3.310000
# max     173.010000   104.880000    104.950000     6.900000     3.910000
#
#            length
# count  1500.00000
# mean    112.67850
# std       0.87273
# min     109.49000
# 25%     112.03000
# 50%     112.96000
# 75%     113.34000
# max     114.44000

# %% [markdown]
# # Partie 3 - Exploration des données

# %% [markdown]
# ## Compte le nombre de vrais billets et faux billets

# %%
billets['is_genuine'].value_counts()
# Out:
# True     1000
# False     500
# Name: is_genuine, dtype: int64

# %% [markdown]
# **Notre échantillon contient 1500 billets : 1000 vrais billets et 500 faux.**

# %% [markdown]
# ## Distribution des données des variables

# %% [markdown]
# ### Visualisation des distributions à l'aide d'histogrammes pour vérifier la forme des variables.

# %%
df_1 = billets.iloc[:,1:]

def distribution (df): 

    variable = df.columns[::]

    for i in variable : 
        plt.figure(figsize=(12,5))
        sns.distplot(df[i])
        plt.show()

# %%
distribution (df_1)
# Out:
# C:\Users\yangq\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\yangq\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
#  ### Teste de normalité (Shapiro-Wilk )
#  Les tests de normalité permettent de s'assurer que la distribution des variables est gaussienne ou non.

# %% [markdown]
# Avec un risque premier alpha de 5%, on émet les deux hypothèses suivantes:
# H0:la variable suit une loi normale
# H1:la variable ne suit pas une loi normale

# %%
df_1.columns.values.tolist()
# Out:
# ['diagonal',
#  'height_left',
#  'height_right',
#  'margin_low',
#  'margin_up',
#  'length']

# %%
#ShapiroTest:

alpha = 0.05

for i in df_1.iloc[:,:]:
    stat, pvalue = stats.shapiro(df_1[i])
    print(pvalue)
    if pvalue > alpha:
        print("Les données suivent une loi normale")
    else:
        print("Nous rejetons l’hypothèse nulle, les données ne suivent pas une loi normale")
# Out:
# 0.323654443025589
# Les données suivent une loi normale
# 0.051517147570848465
# Les données suivent une loi normale
# 0.9806451797485352
# Les données suivent une loi normale
# 6.007587480042917e-25
# Nous rejetons l’hypothèse nulle, les données ne suivent pas une loi normale
# 0.000814208120573312
# Nous rejetons l’hypothèse nulle, les données ne suivent pas une loi normale
# 7.865591300479774e-28
# Nous rejetons l’hypothèse nulle, les données ne suivent pas une loi normale

# %% [markdown]
# **On trouve que les données des 'diagonal','height_left','height_right' suivent une loi normale,
# les données des 'margin_low','margin_up', 'length'ne suivent pas une loi normale.**

# %% [markdown]
# ## Visualiser les caractéristiques des billets selon qu'ils soient vrais ou faux

# %%
# Voir les moyennes de mesures géométriques de vrais billets et faux billets 
billets.groupby("is_genuine").mean()
# Out:
#              diagonal  height_left  height_right  margin_low  margin_up  \
# is_genuine
# False       171.90116    104.19034     104.14362    5.216220    3.35016
# True        171.98708    103.94913     103.80865    4.116185    3.05213
#
#                length
# is_genuine
# False       111.63064
# True        113.20243

# %%
sns.pairplot(billets , hue='is_genuine', corner=True)
plt.show()

# %% [markdown]
# ### Boite à moustache length / is_genuine  et margin_low / is_genuine

# %%
fig, ax = plt.subplots(1,2, figsize=(12,8))
sns.boxplot(x="is_genuine", y="length", data=billets,ax=ax[0])
sns.boxplot(x='is_genuine', y='margin_low',data=billets, ax=ax[1])
plt.show()

# %% [markdown]
# - Les vrais billets ont tendance à être plus long que les faux (Length)
# - Les faux billets ont tendance à avoir une marges inférieures plus longues (margin_low)

# %% [markdown]
# ### Test ANOVA
# Pour tester une variable quantitative (is_genuine) et une variable qualitative (length/margin_low),
# on réalise les tests ANOVA pour vérifier nos observations.

# %%
from scipy import stats

# %% [markdown]
# **Variables 'is_genuine', 'length':**
# - Test de la moyenne (f_oneway)
# Avec un risque premier alpha de 5%, on émets les deux hypothèses suivantes:
# H0: Les moyennes de 'length' des vrais billets et faux billets sont sont égaux
# H1: Les moyennes de 'length' des vrais billets et faux billets ne sont pas égaux

# %%
leng_t = billets[billets.is_genuine == True].length
leng_f = billets[billets.is_genuine == False].length

# %%
fvalue, pvalue= stats.f_oneway(leng_t, leng_f)
print('f_value:',fvalue, ', p_value:',pvalue )
# Out:
# f_value: 3876.6541378261672 , p_value: 0.0

# %% [markdown]
# - p_value < 0.05, nous rejetons l’hypothèse nulle, donc les moyennes de 'length' des vrais billets et faux billets ne sont pas égaux.

# %% [markdown]
# **Variables 'is_genuine', 'margin_low':**
# - Test de la moyenne (f_oneway)
# Avec un risque premier alpha de 5%, on émets les deux hypothèses suivantes:
# H0: Les moyennes de 'margin_low' des vrais billets et faux billets sont sont égaux
# H1: Les moyennes de 'margin_low' des vrais billets et faux billets ne sont pas égaux

# %%
marg_t = billets[billets.is_genuine == True].margin_low
marg_f = billets[billets.is_genuine == False].margin_low

# %%
fvalue, pvalue= stats.f_oneway(marg_t, marg_f)
print('f_value:',fvalue, ', p_value:',pvalue )
# Out:
# f_value: 2423.6497549993314 , p_value: 2.33693391e-315

# %% [markdown]
# - p_value < 0.05, nous rejetons l’hypothèse nulle, donc les moyennes de 'margin_low' des vrais billets et faux billets ne sont pas égaux

# %% [markdown]
# # Partie 4 - Tester les 3 modèles (K-means, K-NN et Régression Logistique)

# %% [markdown]
# ## ACP (Analyse en composantes principales)
# On réalise une analyse en composantes principales pour réduire les 6 variables et représenter nos billets dans un espace à 2 dimensions.

# %% [markdown]
# ### Préparation des données pour l'ACP

# %%
X = billets.drop(columns= ['is_genuine'])
X.head()
# Out:
#    diagonal  height_left  height_right  margin_low  margin_up  length
# 0    171.81       104.86        104.95        4.52       2.89  112.83
# 1    171.46       103.36        103.66        3.77       2.99  113.09
# 2    172.69       104.48        103.50        4.40       2.94  113.16
# 3    171.36       103.91        103.94        3.62       3.01  113.51
# 4    171.73       104.28        103.46        4.04       3.48  112.54

# %%
# Centrage et Réduction
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_scaled
# Out:
# array([[-0.48653957,  2.77412327,  3.16324041,  0.0562999 , -1.128325  ,
#          0.17365114],
#        [-1.63372936, -2.23653528, -0.79966777, -1.08070259, -0.69679916,
#          0.47166629],
#        [ 2.3978233 ,  1.50475644, -1.29119126, -0.1256205 , -0.91256208,
#          0.55190114],
#        ...,
#        [-0.78153123,  1.43794766,  0.61346228,  1.02828427,  1.97866106,
#         -2.71480344],
#        [ 2.29949275,  1.00369058,  1.50434862,  1.04434939,  1.76289814,
#         -1.38519737],
#        [-0.19154792,  0.83666863,  1.135706  ,  1.14716614,  0.38201544,
#         -1.36227312]])

# %%
df_centre = pd.DataFrame(X_scaled, columns=X.columns)
df_centre.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   diagonal      1500 non-null   float64
#  1   height_left   1500 non-null   float64
#  2   height_right  1500 non-null   float64
#  3   margin_low    1500 non-null   float64
#  4   margin_up     1500 non-null   float64
#  5   length        1500 non-null   float64
# dtypes: float64(6)
# memory usage: 70.4 KB

# %% [markdown]
# ### Calcul des composantes principales

# %%
# Nombre de composantes souhaitées
n_comp = 6

# Calcul des composantes principales
pca = PCA(n_components=n_comp)
pca.fit(X_scaled)
# Out:
# PCA(n_components=6)

# %%
# Proportion de variance expliquée
pca.explained_variance_ratio_
# Out:
# array([0.43204935, 0.16957137, 0.13019944, 0.11825183, 0.09666912,
#        0.0532589 ])

# %%
# Cumul de variance expliquée
pca.explained_variance_ratio_.cumsum()
# Out:
# array([0.43204935, 0.60162072, 0.73182015, 0.85007198, 0.9467411 ,
#        1.        ])

# %% [markdown]
# **Graphique Éboulis des valeurs propres**

# %%
# Définition de la fonction pour le graphique Éboulis des valeurs propres
def display_scree_plot(pca):
    scree = pca.explained_variance_ratio_*100
    plt.bar(np.arange(len(scree))+1, scree)
    plt.plot(np.arange(len(scree))+1, scree.cumsum(), c="red", marker='o')
    plt.xlabel("rang de l'axe d'inertie")
    plt.ylabel("pourcentage d'inertie(%)")
    plt.title("Éboulis des valeurs propres")
    plt.show(block=False)

# %%
display_scree_plot(pca)
plt.show()

# %% [markdown]
# Je choisis 2 composantes principales, car les 2 premières dimensions représentent 60% des informations importantes.On va s'intéresser aux axes F1 et F2.

# %% [markdown]
# ### Cercle des corrélations

# %%
# Définition de la fonction pour le graphique Cercle de corrélation
def display_circles(pcs, n_comp, pca, axis_ranks, labels=None, label_rotation=0, lims=None):
    for d1, d2 in axis_ranks:  # On affiche les 3 premiers plans factoriels, donc les 6 premières composantes
        if d2 < n_comp:

            # initialisation de la figure
            fig, ax = plt.subplots(figsize=(10, 10))

            # détermination des limites du graphique
            if lims is not None:
                xmin, xmax, ymin, ymax = lims
            elif pcs.shape[1] < 30:
                xmin, xmax, ymin, ymax = -1, 1, -1, 1
            else:
                xmin, xmax, ymin, ymax = min(pcs[d1, :]), max(
                    pcs[d1, :]), min(pcs[d2, :]), max(pcs[d2, :])

            # affichage des flèches
            # s'il y a plus de 30 flèches, on n'affiche pas le triangle à leur extrémité
            if pcs.shape[1] < 30:
                plt.quiver(np.zeros(pcs.shape[1]), np.zeros(pcs.shape[1]),
                           pcs[d1, :], pcs[d2, :],
                           angles='xy', scale_units='xy', scale=1, color="grey")
            else:
                lines = [[[0, 0], [x, y]] for x, y in pcs[[d1, d2]].T]
                ax.add_collection(LineCollection(
                    lines, axes=ax, alpha=.1, color='black'))

            # affichage des noms des variables
            if labels is not None:
                for i, (x, y) in enumerate(pcs[[d1, d2]].T):
                    if x >= xmin and x <= xmax and y >= ymin and y <= ymax:
                        plt.text(x, y, labels[i], fontsize='14', ha='center',
                                 va='center', rotation=label_rotation, color="blue", alpha=0.5)

            # affichage du cercle
            circle = plt.Circle((0, 0), 1, facecolor='none', edgecolor='b')
            plt.gca().add_artist(circle)

            # définition des limites du graphique
            plt.xlim(xmin, xmax)
            plt.ylim(ymin, ymax)

            # affichage des lignes horizontales et verticales
            plt.plot([-1, 1], [0, 0], color='grey', ls='--')
            plt.plot([0, 0], [-1, 1], color='grey', ls='--')

            # nom des axes, avec le pourcentage d'inertie expliqué
            plt.xlabel('F{} ({}%)'.format(
                d1+1, round(100*pca.explained_variance_ratio_[d1], 1)))
            plt.ylabel('F{} ({}%)'.format(
                d2+1, round(100*pca.explained_variance_ratio_[d2], 1)))

            plt.title("Cercle des corrélations (F{} et F{})".format(d1+1, d2+1))
            plt.show(block=False)

# %%
# Générer le Cercle des corrélations F1 et F2.
pcs = pca.components_ 
display_circles(pcs, n_comp, pca, [(0,1)], labels = np.array(X.columns))

# %% [markdown]
# **- Avec le cercle des corrélations F1-F2 (la projection de la flèche sur F1 correspond au coefficient de corrélation ), on peut trouver des variables qui sont bien corrélées aux composantes principales:**
# - Les variables les plus corrélées positivement à F1 sont 'height' et 'margin'
# - Les variables les plus corrélées  négativement à F1 est 'length'
# - Les variables les plus corrélées positivement à F2 est 'diagonal'

# %% [markdown]
# ### Projection des individus sur le plan factoriel selon le type de billet

# %%
# Définition de la fonction pour le graphique Projection des individus sur les plans factoriels
def display_factorial_planes(X_projected, n_comp, pca, axis_ranks, labels=None, alpha=1, illustrative_var=None):
    for d1, d2 in axis_ranks:
        if d2 < n_comp:

            # initialisation de la figure
            fig = plt.figure(figsize=(10, 10))

            # affichage des points
            if illustrative_var is None:
                plt.scatter(X_projected[:, d1],
                            X_projected[:, d2], alpha=alpha)
            else:
                illustrative_var = np.array(illustrative_var)
                for value in np.unique(illustrative_var):
                    selected = np.where(illustrative_var == value)
                    plt.scatter(
                        X_projected[selected, d1], X_projected[selected, d2], alpha=alpha, label=value)
                plt.legend()

            # affichage des labels des points
            if labels is not None:
                for i, (x, y) in enumerate(X_projected[:, [d1, d2]]):
                    plt.text(x, y, labels[i],
                             fontsize='14', ha='center', va='center')

            # détermination des limites du graphique
            boundary = np.max(np.abs(X_projected[:, [d1, d2]])) * 1.1
            plt.xlim([-boundary, boundary])
            plt.ylim([-boundary, boundary])

            # affichage des lignes horizontales et verticales
            plt.plot([-100, 100], [0, 0], color='grey', ls='--')
            plt.plot([0, 0], [-100, 100], color='grey', ls='--')

            # nom des axes, avec le pourcentage d'inertie expliqué
            plt.xlabel('F{} ({}%)'.format(
                d1+1, round(100*pca.explained_variance_ratio_[d1], 1)))
            plt.ylabel('F{} ({}%)'.format(
                d2+1, round(100*pca.explained_variance_ratio_[d2], 1)))

            plt.title(
                "Projection des individus (sur F{} et F{})".format(d1+1, d2+1))
            plt.show(block=False)

# %%
# Projection des individus sur F1 et F2 

X_projected = pca.transform(X_scaled)
display_factorial_planes(X_projected, n_comp, pca, [(0, 1)], illustrative_var = billets.is_genuine)

plt.show()

# %% [markdown]
# ## K-means (clustering non-supervisé)
# L’algorithme du kmeans est un algorithme itératif qui minimise la somme des distances entre chaque individu et le centroïde du cluster ; c’est la variabilité intra cluster. Attribuer un cluster à chaque objet (ou sujet, ou point), de façon aléatoire.

# %%
# Nombre de clusters souhaités
n_clusters = 2

# %%
# Clustering par K-means
kmeans = KMeans(init='random', n_clusters=2, n_init=10)

# %%
kmeans.fit(X_scaled)
# Out:
# KMeans(init='random', n_clusters=2)

# %%
df_km = billets.copy()

# %%
# Récupération des clusters attribués à chaque individu
df_km['Cluster'] = kmeans.labels_

# %%
df_km.head()
# Out:
#    is_genuine  diagonal  height_left  height_right  margin_low  margin_up  \
# 0        True    171.81       104.86        104.95        4.52       2.89
# 1        True    171.46       103.36        103.66        3.77       2.99
# 2        True    172.69       104.48        103.50        4.40       2.94
# 3        True    171.36       103.91        103.94        3.62       3.01
# 4        True    171.73       104.28        103.46        4.04       3.48
#
#    length  Cluster
# 0  112.83        0
# 1  113.09        1
# 2  113.16        1
# 3  113.51        1
# 4  112.54        1

# %% [markdown]
# ### Projection des individus sur le plan factoriel F1 et F2 par cluster

# %%
display_factorial_planes(X_projected, n_comp, pca, [(0, 1)], illustrative_var=df_km.Cluster)

# %% [markdown]
# Comparer les deux projections des individus, les clusters sont  très similaires; on peux voir que le cluster 0 correspond aux faux billets, et le cluster 1 aux vrais.

# %% [markdown]
# ### Matrice de confusion K- means

# %%
df_km['is_genuine'].replace([True,False],[1,0], inplace=True)
df_km.head()
# Out:
#    is_genuine  diagonal  height_left  height_right  margin_low  margin_up  \
# 0           1    171.81       104.86        104.95        4.52       2.89
# 1           1    171.46       103.36        103.66        3.77       2.99
# 2           1    172.69       104.48        103.50        4.40       2.94
# 3           1    171.36       103.91        103.94        3.62       3.01
# 4           1    171.73       104.28        103.46        4.04       3.48
#
#    length  Cluster
# 0  112.83        0
# 1  113.09        1
# 2  113.16        1
# 3  113.51        1
# 4  112.54        1

# %%
y_vrai = df_km.is_genuine
y_pred = kmeans.labels_

# %%
conf_matrix = pd.crosstab(y_vrai, y_pred )

# Representation graphique de notre matrice de confusion
sns.set(rc={'figure.figsize': (6, 6)}, font_scale=1.4)
sns.heatmap(conf_matrix, annot = True, fmt='', cmap='Blues', cbar=False)

plt.title('Matrice de confusion')
plt.xlabel('Clusters')
plt.ylabel('Type de billet')
plt.show()

# %% [markdown]
# Vrais positifs : 990
# Vrais négatifs : 486
# Faux positifs : 14
# Faux négatifs : 10
#
# Donc nous avons 10 vrais billets détectés comme des faux billets (cluster 0), et 14 faux billets détectés comme des vrais billets (cluster 1).

# %% [markdown]
# ### Classification report

# %%
print(classification_report(y_vrai,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.97      0.98       500
#            1       0.99      0.99      0.99      1000
#
#     accuracy                           0.98      1500
#    macro avg       0.98      0.98      0.98      1500
# weighted avg       0.98      0.98      0.98      1500

# %% [markdown]
# Le rapport  nous aide à mieux comprendre comment on été interprétés les résultats obtenus. On observe d'ailleurs une exactitude des résultats à hauteur de 98% (accuracy).
# ("Accuracy score" est utilisé pour mesurer les performances du modèle en termes de ratio de la somme des vrais positifs et des vrais négatifs sur l'ensemble des prédictions effectuées.)

# %% [markdown]
# ## Régression logistique (classification supervisé)
# L'objectif de la régression logistique est de modéliser, de classifier, une variable binaire prenant ses valeurs dans {0,1} en fonction de variables explicatives quantitatives (et potentiellement qualitatives).

# %% [markdown]
# ### Préparer les données

# %%
X = billets.drop(['is_genuine'], axis=1)
y = billets['is_genuine']

# %%
# Séparer training / testing set
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.20, random_state=5)

# %%
X_train.shape
# Out:
# (1200, 6)

# %%
X_test.shape
# Out:
# (300, 6)

# %% [markdown]
# ###  Création du modèle de régression logistique

# %%
model_logit = LogisticRegression()
model_logit.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
# Coefficients
pd.DataFrame(np.concatenate([model_logit.intercept_.reshape(-1, 1), model_logit.coef_],
             axis=1), index=["coef"], columns=["constante"]+list(X.columns)).T
# Out:
#                   coef
# constante    -0.018850
# diagonal     -0.217240
# height_left  -1.347944
# height_right -2.069855
# margin_low   -3.531494
# margin_up    -3.166300
# length        3.728162

# %% [markdown]
# ### Prédictions

# %%
y_pred_test = model_logit.predict(X_test)

# %% [markdown]
# ### Matrice de confusion (régression logistique)

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
font = {'family' : 'normal', 'size': 20}
plt.rc('font', **font)

cm = confusion_matrix(y_test, y_pred_test)
cmp = ConfusionMatrixDisplay(cm)
figure,ax = plt.subplots(figsize=(7,7))
cmp.plot(ax=ax)

# %% [markdown]
# Vrais positifs : 194
# Vrais négatifs : 105
# Faux positifs : 0
# Faux négatifs : 1
#
# Donc nous avons 1 vrai billet détecté comme un faux, et 0 faux billets détectés comme des vrais billets.

# %% [markdown]
# ### Évaluation du modèle avec les scores

# %% [markdown]
# #### Accuracy score
# "Accuracy score" est utilisé pour mesurer les performances du modèle en termes de ratio de la somme des vrais positifs et des vrais négatifs sur l'ensemble des prédictions effectuées.

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_test, y_pred_test)
print("Le taux de prédiction correcte sur toutes les données de test = {}%".format( round(accuracy, 4)))
# Out:
# Le taux de prédiction correcte sur toutes les données de test = 0.9967%

# %% [markdown]
#  #### Le coefficient de détermination R2
#  On utilise la methode .score pour trouver Le coefficient de détermination  R2.
# - Si R2=1: toute la variation est expliquée par le modèle.
# - Si R2=0: aucune variation n'est expliquée par le modèle.

# %%
print('R2 de Train_score:', round(model_logit.score(X_train,y_train),3))
print('R2 de Test_score:', round(model_logit.score(X_test,y_test),3))
# Out:
# R2 de Train_score: 0.99
# R2 de Test_score: 0.997

# %% [markdown]
# #### Cross-Validation ( Régression logistique)

# %%
from sklearn.model_selection import cross_val_score

# Calcul la moyenne de 'accuracy scores'
scores = cross_val_score(
    estimator=model_logit,  
    X=X,  
    y=y,  
    scoring="accuracy",  
    cv=10, 
    n_jobs=-1  
)

print(scores)
print("average accuracy scores = %.4f" % np.mean(scores))
print("std of scores = %.4f" % np.std(scores))
# Out:
# [0.98666667 0.98666667 0.98666667 0.98666667 1.         0.99333333
#  0.98       0.99333333 0.98666667 1.        ]
# average accuracy scores = 0.9900
# std of scores = 0.0061

# %%
# Calcul de la moyenne de 'recall scores'
#Le recall permet de savoir le pourcentage de positifs bien prédit par notre modèle.

scores = cross_val_score(
    estimator=model_logit,  
    X=X,  
    y=y,  
    scoring="recall",  
    cv=10, 
    n_jobs=-1  
)

print(scores)
print("average recall scores = %.4f" % np.mean(scores))
print("std of scores = %.4f" % np.std(scores))
# Out:
# [0.99 1.   1.   1.   1.   0.99 0.98 0.99 1.   1.  ]
# average recall scores = 0.9950
# std of scores = 0.0067

# %% [markdown]
# ## K-NN (classification supervisé)
# Diminutif de K Nearest Neighbors.
# C’est un algorithme qui peut servir autant pour la classification que pour la régression. Il est surnommé « nearest neighbors »  car le principe de ce modèle consiste en effet à choisir les k données les plus proches du point étudié afin d’en prédire sa valeur.

# %% [markdown]
# ### Préparer les données

# %%
X = billets.drop(['is_genuine'], axis=1)
y = billets['is_genuine']

# %%
# Séparer training / testing set
X_train_k, X_test_k, y_train_k, y_test_k = train_test_split(X,y,test_size=0.2, random_state=5)

# %%
X_train_k.shape
# Out:
# (1200, 6)

# %%
X_test_k.shape
# Out:
# (300, 6)

# %% [markdown]
# ### Choisir le nombre optimal de K

# %% [markdown]
# Pour trouver le k optimal, on va simplement tester le modèle pour tous les k de 2 à 15, mesurer l’erreur test et afficher la performance en fonction de k

# %%
errors = []
for k in range(2,15):
    knn = neighbors.KNeighborsClassifier(k)
    errors.append(100*(1 - knn.fit(X_train_k, y_train_k).score(X_test_k, y_test_k)))
plt.figure(figsize=(8, 6))
plt.plot(range(2,15), errors, 'o-')
plt.title('Nombre optimal de K')
plt.ylabel("Taux d'erreur de prédiction")
plt.xlabel('Nombre de K')
plt.show()
plt.show()

# %% [markdown]
# **Comme on peut le voir, le k-NN le plus performant est celui pour lequel k = 3 . On connaît donc notre classifieur final optimal : 3-nn. Ce qui veut dire que c'est celui qui classifie le mieux les données.**

# %% [markdown]
#  ### Création de modèle K-NN

# %%
# On récupère le classifieur le plus performant
knn = neighbors.KNeighborsClassifier(3)
knn.fit(X_train_k, y_train_k)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %% [markdown]
# ### Prédictions

# %%
y_pred_test_k= knn.predict(X_test_k)

# %% [markdown]
# ### Matrice de confusion (K-NN)

# %%
font = {'family' : 'normal', 'size': 20}
plt.rc('font', **font)

cm_k = confusion_matrix(y_test_k, y_pred_test_k)
cmp = ConfusionMatrixDisplay(cm_k)
figure,ax = plt.subplots(figsize=(7,7))
cmp.plot(ax=ax)

# %% [markdown]
# Vrais positifs : 195
# Vrais négatifs : 104
# Faux positifs : 1
# Faux négatifs : 0
#
# Donc nous avons 0 vrai billet détecté comme un faux billet , et 1 faux billets détecté comme un vrai billet.

# %% [markdown]
# ### Évaluation du modèle avec les scores

# %% [markdown]
# #### Accuracy score

# %%
accuracy = accuracy_score(y_test_k, y_pred_test_k)
print("Le taux de prédiction correcte sur toutes les données de test = {}%".format( round(accuracy, 4)))
# Out:
# Le taux de prédiction correcte sur toutes les données de test = 0.9967%

# %% [markdown]
#  #### Le coefficient de détermination R2

# %%
print('R2 de Train_score:', round(model_logit.score(X_train_k,y_train_k),3))
print('R2 de Test_score:', round(model_logit.score(X_test_k,y_test_k),3))
# Out:
# R2 de Train_score: 0.99
# R2 de Test_score: 0.997

# %% [markdown]
# #### Cross-Validation (K-NN )

# %%
# Calcul de la moyenne des 'accuracy scores'
scores = cross_val_score(
    estimator= knn,  
    X=X,  
    y=y,  
    scoring="accuracy",  
    cv=10, 
    n_jobs=-1  
)

print(scores)
print("average accurancy score  = %.4f" % np.mean(scores))
print("std of scores = %.4f" % np.std(scores))
# Out:
# [0.98       0.98666667 0.98666667 0.98666667 1.         0.99333333
#  0.99333333 0.99333333 0.98       1.        ]
# average accurancy score  = 0.9900
# std of scores = 0.0068

# %%
# Calcul de la moyenne des 'recall scores'
#Le recall permet de savoir le pourcentage de positifs bien prédits par notre modèle.
scores = cross_val_score(
    estimator=knn,  
    X=X,  
    y=y,  
    scoring="recall",  
    cv=10, 
    n_jobs=-1  
)

print(scores)
print("average recall scores = %.4f" % np.mean(scores))
print("std of scores = %.4f" % np.std(scores))
# Out:
# [0.99 1.   1.   1.   1.   0.99 0.99 0.99 1.   1.  ]
# average recall scores = 0.9960
# std of scores = 0.0049

# %% [markdown]
# # Conclusion

# %%
from pandas import Series,DataFrame

# %%
df = {'Accuracy': {'K-means':0.98, 'Régression logistique': 0.99, 'K-NN':0.99},
        'Recall':{'K-means':0.98, 'Régression logistique': 0.995, 'K-NN':0.996}}
score = DataFrame(df)

# %%
score
# Out:
#                        Accuracy  Recall
# K-means                    0.98   0.980
# Régression logistique      0.99   0.995
# K-NN                       0.99   0.996

# %% [markdown]
# - Accuracy = (Vrai positif + Vrai négatif) / Total
# - Recall = Vrai positif / (Vrai positif + faux négatif)
#
# Après avoir testé les 3 modèles, il apparait que le modèle de régression logistique et le modèle de K-NN ont le score le plus élevé et donc sont plus adaptés pour faire de la prediction.
#
# Pour notre programme de détection, je décide de choisir le  modèle de régression logistique; en effet, un modèle utilisant cette méthode sera plus rapide dans le traitement d'un grand nombre de données qu'un modèle du type K-NN.

# %% [markdown]
# # Programme de détection avec régression logistique

# %% [markdown]
# ## Importation et prédiction des données du fichier 'billets_production'

# %%
billets_production = pd.read_csv("D:/Open_work/P10/doc_origine/billets_production.csv")

# %%
billets_production.head()
# Out:
#    diagonal  height_left  height_right  margin_low  margin_up  length   id
# 0    171.76       104.01        103.54        5.21       3.30  111.42  A_1
# 1    171.87       104.17        104.13        6.00       3.31  112.09  A_2
# 2    172.00       104.58        104.29        4.99       3.39  111.57  A_3
# 3    172.49       104.55        104.34        4.44       3.03  113.20  A_4
# 4    171.65       103.63        103.56        3.77       3.16  113.33  A_5

# %%
billets_values=billets_production.drop('id', axis=1)

# %%
billets_values
# Out:
#    diagonal  height_left  height_right  margin_low  margin_up  length
# 0    171.76       104.01        103.54        5.21       3.30  111.42
# 1    171.87       104.17        104.13        6.00       3.31  112.09
# 2    172.00       104.58        104.29        4.99       3.39  111.57
# 3    172.49       104.55        104.34        4.44       3.03  113.20
# 4    171.65       103.63        103.56        3.77       3.16  113.33

# %%
y_pred_production = model_logit.predict(billets_values)

# %%
y_pred_production
# Out:
# array([False, False, False,  True,  True])

# %%
proba_true = model_logit.predict_proba(billets_values)[:, 1]
proba_true
# Out:
# array([4.96445108e-03, 8.36930792e-04, 1.32880339e-03, 9.14310883e-01,
#        9.99607925e-01])

# %%
billets_production['Prediction'] = y_pred_production
billets_production['Probability_is_true'] = proba_true.round(3)

# %%
billets_production
# Out:
#    diagonal  height_left  height_right  margin_low  margin_up  length   id  \
# 0    171.76       104.01        103.54        5.21       3.30  111.42  A_1
# 1    171.87       104.17        104.13        6.00       3.31  112.09  A_2
# 2    172.00       104.58        104.29        4.99       3.39  111.57  A_3
# 3    172.49       104.55        104.34        4.44       3.03  113.20  A_4
# 4    171.65       103.63        103.56        3.77       3.16  113.33  A_5
#
#    Prediction  Probability_is_true
# 0       False                0.005
# 1       False                0.001
# 2       False                0.001
# 3        True                0.914
# 4        True                1.000

# %%
billets_predict = billets_production[['id','Prediction','Probability_is_true']].set_index("id")

# %%
billets_predict
# Out:
#      Prediction  Probability_is_true
# id
# A_1       False                0.005
# A_2       False                0.001
# A_3       False                0.001
# A_4        True                0.914
# A_5        True                1.000

# %% [markdown]
# ## Fonction du modèle de détection avec régression logistique

# %%
def verif_billet_rl(csv):
    billet_test= pd.read_csv(csv)
    billet_value=billet_test.drop('id', axis=1)
    y_pred = model_logit.predict(billet_value)
    proba_true = model_logit.predict_proba(billet_value)[:, 1]
    billet_test['Prediction'] = y_pred
    billet_test['Probability_is_true'] = proba_true.round(3)
    billets_predict_rl = billet_test[['id','Prediction','Probability_is_true']].set_index("id")
    return billets_predict_rl

# %%
# Tester le fonction
verif_billet_rl("D:/Open_work/P10/doc_origine/billets_production.csv")
# Out:
#      Prediction  Probability_is_true
# id
# A_1       False                0.005
# A_2       False                0.001
# A_3       False                0.001
# A_4        True                0.914
# A_5        True                1.000
